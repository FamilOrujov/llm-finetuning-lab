# %% [markdown]
# #Llama 3.2 Financial Sentiment Fine-Tuning with Unsloth
#
# **Model:** `Llama-3.2-3B-Instruct` (4-bit QLoRA)
# **Dataset:** [Financial Sentiment Analysis](https://www.kaggle.com/datasets/sbhatti/financial-sentiment-analysis) (5.8K samples)
# **Framework:** Unsloth + PEFT + TRL
#
# ---
#
# ### 🚀 Run in Google Colab
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1I2_FX7USgFMyROr29oaEljxd1QoubYD-?usp=sharing)
